# %% [markdown]
# This notebook is indent to see which parameter are b

# %%
import pandas as pd

# %%
catboost = pd.read_csv('results_catboost.csv')

# %%
catboost.head()
# Out:
#   Iterations learning_rate  depth  l2_leaf_reg  model_size_reg  rsm  \
# 0        200          0.01    3.0          0.0             0.0  NaN
# 1        200          0.01    3.0          0.0             0.0  NaN
# 2        200          0.01    3.0          0.0             0.0  NaN
# 3        200          0.01    3.0          0.0             0.0  NaN
# 4        200          0.01    3.0          0.0             0.0  NaN
#
#   random_seed boosting_type  bagging_temperature  max_bin  \
# 0           1         Plain                  0.0    255.0
# 1           1         Plain                  0.0    255.0
# 2           1         Plain                  0.0    128.0
# 3           1         Plain                  0.0    128.0
# 4           1         Plain                  1.0    255.0
#
#    approx_on_full_history          Y test  \
# 0                     NaN  18-05-30-17-11
# 1                     NaN  18-05-30-17-11
# 2                     NaN  18-05-30-17-11
# ...

# %%
catboost.sort_values(by=['Log loss']).head(50)
# Out:
#      Iterations learning_rate  depth  l2_leaf_reg  model_size_reg  rsm  \
# 4906        250          0.01    4.0          3.0            10.0  0.5
# 4326        250          0.01    4.0          1.0            10.0  NaN
# 4702        250          0.01    4.0          3.0             0.0  NaN
# 4811        250          0.01    4.0          3.0            10.0  NaN
# 4639        250          0.01    4.0          2.0            10.0  0.5
# 4314        250          0.01    4.0          1.0             0.0  0.5
# 4583        250          0.01    4.0          2.0             0.0  0.5
# 4424        250          0.01    4.0          1.0            10.0  NaN
# 4561        250          0.01    4.0          2.0             0.0  0.5
# 4541        250          0.01    4.0          2.0             0.0  NaN
# 4569        250          0.01    4.0          2.0             0.0  0.5
# 4787        250          0.01    4.0          3.0             0.0  0.5
# ...
